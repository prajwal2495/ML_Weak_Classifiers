# %%
import pandas as pd
import numpy as np
import copy

# %%
class my_KMeans:

    def __init__(self, n_clusters=8, init = "k-means++", n_init = 10, max_iter=50, tol=1e-4):
        # init = {"k-means++", "random"}
        # stop when either # iteration is greater than max_iter or the delta of self.inertia_ is smaller than tol.
        # repeat n_init times and keep the best run (cluster_centers_, inertia_) with the lowest inertia_.
        self.n_clusters = int(n_clusters)
        self.init = init
        self.n_init = n_init
        self.max_iter = int(max_iter)
        self.tol = tol

        self.classes_ = range(n_clusters)
        
        # Centroids
        self.cluster_centers_ = None
        
        # Sum of squared distances of samples to their closest cluster center.
        self.inertia_ = None

    def dist(self, a, b):
        # Compute Euclidean distance between a and b
        return np.sum((np.array(a)-np.array(b))**2)**(0.5)

    def initiate(self, X):
        # Initiate cluster centers
        # Input X is numpy.array
        # Output cluster_centers (list)
                    
        self.X = X
        self.n_samples, self.n_features = X.shape
    
        if self.init == "random":
            random_sample_indices = np.random.choice(self.n_samples, self.n_clusters, replace = False)
            cluster_centers = [self.X[index] for index in random_sample_indices]
            #print(cluster_centers)

        elif self.init == "k-means++":
            
            random_index = np.random.randint(135)
            cluster_centers = [X[random_index]]
            #cluster_centers = [np.random.choice(self.n_samples)]
            
            for _ in range(1, self.n_clusters):
                
                D2 = np.array([min([np.inner(c-x,c-x) for c in cluster_centers]) for x in X])
                
                probability = D2 / D2.sum()
                
                cumulative_probability = probability.cumsum()
                
                r = np.random.rand()
                
                for j,p in enumerate(cumulative_probability):
                
                    if r < p:
                        i = j
                        break
                        
                cluster_centers.append(X[i])

        else:
            raise Exception("Unknown value of self.init.")
        return cluster_centers
            



    def fit_once(self, X):
        # Fit once
        # Input X is numpy.array
        # Output: cluster_centers (list), inertia

        # Initiate cluster centers
        cluster_centers = self.initiate(X)
        #print("iam cluster_centers:")
        #print(cluster_centers)
        
        last_inertia = None
        
        # Iterate
        for i in range(self.max_iter+1):
            
            # Assign each training data point to its nearest cluster_centers
            clusters = [[] for i in range(self.n_clusters)]
            # print("Iam clusters")
            # print(clusters)
            inertia = 0
            
            for x in X:
                # print("I am individual feature:")
                # print(x)
                # set_trace()
                
                # calculate distances between x and each cluster center
                dists = [self.dist(x, center) for center in cluster_centers]
                # print("Iam distance between feature and cluster_center")
                # print(dists)
                
                
                # calculate inertia
                # "write your own code"
                inertia += (min(dists) * min(dists))
                # inertia += (np.argmin(dists) ** 2)
                # print("Iam inertia")
                # print(inertia)
                
                # find the cluster that x belongs to
                # cluster_id = "write your own code"
                cluster_id = np.argmin(dists)
                # print("I am cluster id with min distance:")
                # print(cluster_id)
                
                # add x to that cluster
                clusters[cluster_id].append(x)
                # print("I am the final cluster")
                # print(clusters)
                

            # I think this is checking convergence or that elbow curve thingy
            if (last_inertia and last_inertia - inertia < self.tol) or i==self.max_iter:
                break
            
            
            # Update cluster centers
            # "Write your own code"
            
            old_cluster_centers = copy.deepcopy(cluster_centers)
            cluster_centers = self.update_cluster_centers2(clusters)
            
#             for cluster_data in clusters:
#                 for index, centers in enumerate(old_cluster_centers):
#                     cluster_centers[index] = np.mean(cluster_data)
            #cluster_centers = self.update_cluster_centers(clusters, old_cluster_centers)
            
            last_inertia = inertia
            
            

        return cluster_centers, inertia


    def update_cluster_centers2(self, clusters):
        cluster_centers = np.zeros((self.n_clusters, self.n_features))
       
        for cluster_index, cluster_data in enumerate(clusters):
            
            cluster_data_mean = np.mean(clusters[cluster_index], axis = 0)
            cluster_centers[cluster_index] = cluster_data_mean
        
        return cluster_centers
        
#     def update_cluster_centers(self, clusters, old_clusters_centers):
        
#         cluster_centers = np.zeros((self.n_clusters, self.n_features))
        
#         for cluster_index, centers in enumerate(old_clusters_centers):
#             for x in clusters:
#                 mean_of_centroids = np.mean(clusters[cluster_index])
#                 cluster_centers[cluster_index] = mean_of_centroids
        
#         return cluster_centers


    def fit(self, X):
        # X: pd.DataFrame, independent variables, float
        # repeat self.n_init times and keep the best run
        # (self.cluster_centers_, self.inertia_) with the lowest self.inertia_.
        
        X_feature = X.to_numpy()
        # print(X_feature)
        
        
        for i in range(self.n_init):
            cluster_centers, inertia = self.fit_once(X_feature)
            
            if self.inertia_==None or inertia < self.inertia_:
                self.inertia_ = inertia
                self.cluster_centers_ = cluster_centers
        
        return


    def transform(self, X):
        # Transform to cluster-distance space
        # X: pd.DataFrame, independent variables, float
        # return dists = list of [dist to centroid 1, dist to centroid 2, ...]
        dists = [[self.dist(x,centroid) for centroid in self.cluster_centers_] for x in X.to_numpy()]
        return dists

    def predict(self, X):
        # X: pd.DataFrame, independent variables, float
        # return predictions: list
        predictions = [np.argmin(dist) for dist in self.transform(X)]
        return predictions


    def fit_predict(self, X):
        self.fit(X)
        return self.predict(X)

    def fit_transform(self, X):
        self.fit(X)
        return self.transform(X)

# %%
#  Load training data
data_train = pd.read_csv("../data/Iris_train.csv")
# Separate independent variables and dependent variables
independent = ["SepalLengthCm",	"SepalWidthCm",	"PetalLengthCm",	"PetalWidthCm"]
X = data_train[independent]
y = data_train["Species"]
# Train model
clf = my_KMeans(n_clusters=8)
y_p = clf.fit_predict(X)
#Show training results
print("Classes:")
print()
print([(y[i], y_p[i]) for i in range(len(y))])
print()
print("Centroids:")
print()
print(clf.cluster_centers_)
print()
print("Inertia: %f" %clf.inertia_)
print()

# Load testing data
data_test = pd.read_csv("../data/Iris_test.csv")
X_test = data_test[independent]
# Transform test data to cluster-distance space
dists = clf.transform(X_test)
print()
print("Testing data:")
print()
print(dists)
print()
print("Predictions:")
print(clf.predict(X_test))
print()
# Out:
# Classes:
#
# [('Iris-setosa', 7), ('Iris-setosa', 1), ('Iris-setosa', 1), ('Iris-setosa', 1), ('Iris-setosa', 7), ('Iris-setosa', 7), ('Iris-setosa', 1), ('Iris-setosa', 7), ('Iris-setosa', 1), ('Iris-setosa', 1), ('Iris-setosa', 7), ('Iris-setosa', 1), ('Iris-setosa', 1), ('Iris-setosa', 7), ('Iris-setosa', 7), ('Iris-setosa', 7), ('Iris-setosa', 7), ('Iris-setosa', 1), ('Iris-setosa', 7), ('Iris-setosa', 1), ('Iris-setosa', 1), ('Iris-setosa', 7), ('Iris-setosa', 7), ('Iris-setosa', 7), ('Iris-setosa', 1), ('Iris-setosa', 1), ('Iris-setosa', 7), ('Iris-setosa', 7), ('Iris-setosa', 7), ('Iris-setosa', 1), ('Iris-setosa', 1), ('Iris-setosa', 7), ('Iris-setosa', 1), ('Iris-setosa', 1), ('Iris-setosa', 7), ('Iris-setosa', 7), ('Iris-setosa', 1), ('Iris-setosa', 1), ('Iris-setosa', 7), ('Iris-setosa', 7), ('Iris-setosa', 1), ('Iris-setosa', 7), ('Iris-setosa', 1), ('Iris-setosa', 7), ('Iris-setosa', 1), ('Iris-versicolor', 5), ('Iris-versicolor', 5), ('Iris-versicolor', 5), ('Iris-versicolor', 0), ('Iris-versicolor', 5), ('Iris-versicolor', 6), ('Iris-versicolor', 5), ('Iris-versicolor', 0), ('Iris-versicolor', 5), ('Iris-versicolor', 0), ('Iris-versicolor', 5), ('Iris-versicolor', 6), ('Iris-versicolor', 6), ('Iris-versicolor', 3), ('Iris-versicolor', 0), ('Iris-versicolor', 3), ('Iris-versicolor', 6), ('Iris-versicolor', 3), ('Iris-versicolor', 5), ('Iris-versicolor', 5), ('Iris-versicolor', 5), ('Iris-versicolor', 5), ('Iris-versicolor', 5), ('Iris-versicolor', 5), ('Iris-versicolor', 0), ('Iris-versicolor', 0), ('Iris-versicolor', 0), ('Iris-versicolor', 6), ('Iris-versicolor', 3), ('Iris-versicolor', 6), ('Iris-versicolor', 5), ('Iris-versicolor', 5), ('Iris-versicolor', 5), ('Iris-versicolor', 6), ('Iris-versicolor', 6), ('Iris-versicolor', 6), ('Iris-versicolor', 5), ('Iris-versicolor', 6), ('Iris-versicolor', 0), ('Iris-versicolor', 6), ('Iris-versicolor', 6), ('Iris-versicolor', 6), ('Iris-versicolor', 5), ('Iris-versicolor', 0), ('Iris-versicolor', 6), ('Iris-virginica', 2), ('Iris-virginica', 3), ('Iris-virginica', 4), ('Iris-virginica', 2), ('Iris-virginica', 2), ('Iris-virginica', 4), ('Iris-virginica', 6), ('Iris-virginica', 4), ('Iris-virginica', 2), ('Iris-virginica', 4), ('Iris-virginica', 2), ('Iris-virginica', 3), ('Iris-virginica', 2), ('Iris-virginica', 3), ('Iris-virginica', 3), ('Iris-virginica', 2), ('Iris-virginica', 2), ('Iris-virginica', 4), ('Iris-virginica', 4), ('Iris-virginica', 3), ('Iris-virginica', 2), ('Iris-virginica', 3), ('Iris-virginica', 3), ('Iris-virginica', 2), ('Iris-virginica', 4), ('Iris-virginica', 4), ('Iris-virginica', 4), ('Iris-virginica', 2), ('Iris-virginica', 3), ('Iris-virginica', 3), ('Iris-virginica', 4), ('Iris-virginica', 2), ('Iris-virginica', 2), ('Iris-virginica', 3), ('Iris-virginica', 2), ('Iris-virginica', 2), ('Iris-virginica', 2), ('Iris-virginica', 3), ('Iris-virginica', 2), ('Iris-virginica', 2), ('Iris-virginica', 2), ('Iris-virginica', 3), ('Iris-virginica', 2), ('Iris-virginica', 2), ('Iris-virginica', 3)]
#
# Centroids:
#
# [[5.37777778 2.47777778 3.56666667 1.1       ]
#  [4.73181818 3.12727273 1.43181818 0.19545455]
#  [6.56190476 3.07619048 5.52857143 2.16666667]
#  [6.01176471 2.7        5.01764706 1.77647059]
#  [7.48       3.15       6.29       2.08      ]
#  [6.43333333 2.98333333 4.59444444 1.43888889]
#  [5.62666667 2.77333333 4.21333333 1.30666667]
#  [5.21304348 3.62173913 1.53043478 0.2826087 ]]
#
# Inertia: 26.025344
#
#
# Testing data:
#
# [[2.9186924182069554, 0.5673448380740385, 5.385663761288842, 4.602026783823746, 6.402452655037756, 4.30756942149371, 3.6000432096172283, 1.1995115578082975], [2.984383221015114, 1.3987228531180536, 4.902879897827093, 4.335266182366697, 5.743465852601545, 3.8068124445071256, 3.4408784408119453, 0.7769237967853364], [2.9257266692584047, 1.6135979508872205, 4.673954464918979, 4.153999198671149, 5.522445110637135, 3.633125206407302, 3.2917540072800775, 0.926025717509835], [2.7660418750121964, 1.0501377320134466, 4.799022009211665, 4.186863622046862, 5.710639193645489, 3.7203104543227585, 3.2604157880722995, 0.42339433147408345], [2.540972886489847, 0.5351874623295184, 4.779783104975817, 4.091289591196293, 5.733009680787222, 3.680525157107171, 3.1198789150293074, 0.21193143664267702], [1.6672961774111628, 3.8469667132121095, 1.2829069881078894, 0.8873973452985457, 2.0739816778361386, 0.2324719550323071, 1.0549776195625074, 3.591917517925009], [0.5311297067874272, 2.818618001435549, 2.2883021064999807, 1.4317216872071798, 3.402263952135402, 1.4440063438183552, 0.5425044802682392, 2.7772604853349003], [0.6208317797643994, 2.503464541539145, 3.0122990519255057, 2.1023384574371873, 4.052579425501739, 2.10043352374083, 1.2623963103734288, 2.658808522613914], [1.0519235760627024, 3.278035467917579, 1.6289473250400406, 0.920583536917158, 2.687638368531005, 0.6663656727927563, 0.40452990550074797, 3.0768634755024324], [0.8136945160390963, 3.1162431025804396, 2.1865700161152293, 1.3742818193628044, 3.0827585049756987, 1.1607654988023532, 0.7795155190529842, 3.0420462469561564], [4.01551005323786, 6.318808013442393, 1.6648016776332062, 2.395916364340271, 0.5877074101966046, 2.527106137877625, 3.311139448051749, 6.0443399448260715], [1.7797905272777623, 4.152662692540357, 0.8600348039152714, 0.31220834140507314, 1.8987890878135998, 0.5672926825319723, 1.0833487178394787, 3.9607478623979087], [2.8240807528761347, 5.074272736230572, 0.3209255322951274, 1.1848816973344654, 0.9896464014990413, 1.3530372783272495, 2.066150473169313, 4.79611728597143], [3.202063377971025, 5.4350769988539325, 0.8827138117585939, 1.6209485027115795, 0.4933558553417611, 1.6555089478898057, 2.4683957903419325, 5.138613598670961], [1.6706249292767625, 4.0226707751553885, 0.9340861881018919, 0.30554279795813066, 2.0147952749597176, 0.5105975680937089, 0.9575895664520244, 3.8264698425019055]]
#
# Predictions:
# [1, 7, 7, 7, 7, 5, 0, 0, 6, 6, 4, 3, 2, 4, 3]
